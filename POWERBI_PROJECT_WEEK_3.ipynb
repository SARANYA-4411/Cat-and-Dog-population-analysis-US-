# %% [markdown]
# <a href="https://colab.research.google.com/github/SARANYA-4411/Cat-and-Dog-population-analysis-US-/blob/main/POWERBI_PROJECT_WEEK_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # POWERBI PROJECT - CAT AND DOG POPULATION IN U.S

# %% [markdown]
# [link text](https://drive.google.com/file/d/1RVhxqiDcVoXHcIfmxp1LD7q4KOBdrXxk/view?usp=sharing)

# %% [markdown]
# ![powerbi project - saranya n.png](data:image/png;base64,...)
